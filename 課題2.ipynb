# %%
import pandas as pd
df1=pd.read_csv('orders_1.csv')
df2=pd.read_csv('orders_2.csv')
df3=pd.read_csv('orders_3.csv')
df1
# Out:
#    order_id product  quantity
# 0         1       A         2
# 1         2       B         1
# 2         3       C         4

# %%
df2
# Out:
#    order_id product  quantity
# 0         4       A         3
# 1         5       B         2
# 2         6       D         1

# %%
df3
# Out:
#    order_id product  quantity
# 0         7       C         2
# 1         8       A         1
# 2         9       D         3

# %%
df=pd.concat([df1,df2,df3])
df
# Out:
#    order_id product  quantity
# 0         1       A         2
# 1         2       B         1
# 2         3       C         4
# 0         4       A         3
# 1         5       B         2
# 2         6       D         1
# 0         7       C         2
# 1         8       A         1
# 2         9       D         3

# %%
df4 = df.groupby('product')['quantity'].sum().reset_index()
df4
# Out:
#   product  quantity
# 0       A         6
# 1       B         3
# 2       C         6
# 3       D         4

# %%
df4.to_csv('product_quantities.csv', index=False)
