# %%
import pandas as pd
df=pd.read_csv('python 課題CSV.csv')

# %%
df['sales_per_item'] = df['price'] * df['quantity']
display(df)
# Out:
#        date product  quantity  price  sales_per_item
# 0  2024/1/1       A         3   1000            3000
# 1  2024/1/1       B         2   1500            3000
# 2  2024/1/2       A         1   1000            1000
# 3  2024/1/2       C         5    500            2500

# %%
sales=df['sales_per_item'].sum()
print(sales)
# Out:
# 9500

# %%
df.to_csv('kadai1.csv')
